# %%
import pandas as pd

# %%
df = pd.read_csv("./data/auto-mpg.csv", header=None)
df.head()
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
df.columns = [
    "mpg",'cylinders','displacement',"horsepower","weight","acceleration","model year","origin","name"
]
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
mpg_to_kpl = 1.60934 / 3.78541

df["kpl"] = df["mpg"] * mpg_to_kpl
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name       kpl
# 0       1  chevrolet chevelle malibu  7.652571
# 1       1          buick skylark 320  6.377143
# 2       1         plymouth satellite  7.652571
# 3       1              amc rebel sst  6.802286
# 4       1                ford torino  7.227428

# %%
df["kpl"] = df["kpl"].round(2)
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name   kpl
# 0       1  chevrolet chevelle malibu  7.65
# 1       1          buick skylark 320  6.38
# 2       1         plymouth satellite  7.65
# 3       1              amc rebel sst  6.80
# 4       1                ford torino  7.23

# %%
# 자료형 변환
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower          str
# weight          float64
# acceleration    float64
# model year        int64
# origin            int64
# name                str
# kpl             float64
# dtype: object

# %%
df["horsepower"].unique()
# Out:
# <StringArray>
# ['130.0', '165.0', '150.0', '140.0', '198.0', '220.0', '215.0', '225.0',
#  '190.0', '170.0', '160.0', '95.00', '97.00', '85.00', '88.00', '46.00',
#  '87.00', '90.00', '113.0', '200.0', '210.0', '193.0',     '?', '100.0',
#  '105.0', '175.0', '153.0', '180.0', '110.0', '72.00', '86.00', '70.00',
#  '76.00', '65.00', '69.00', '60.00', '80.00', '54.00', '208.0', '155.0',
#  '112.0', '92.00', '145.0', '137.0', '158.0', '167.0', '94.00', '107.0',
#  '230.0', '49.00', '75.00', '91.00', '122.0', '67.00', '83.00', '78.00',
#  '52.00', '61.00', '93.00', '148.0', '129.0', '96.00', '71.00', '98.00',
#  '115.0', '53.00', '81.00', '79.00', '120.0', '152.0', '102.0', '108.0',
#  '68.00', '58.00', '149.0', '89.00', '63.00', '48.00', '66.00', '139.0',
#  '103.0', '125.0', '133.0', '138.0', '135.0', '142.0', '77.00', '62.00',
#  '132.0', '84.00', '64.00', '74.00', '116.0', '82.00']
# Length: 94, dtype: str

# %%
import numpy as np

df["horsepower"] = df["horsepower"].replace("?",np.nan)
df["horsepower"].unique()
# Out:
# <StringArray>
# ['130.0', '165.0', '150.0', '140.0', '198.0', '220.0', '215.0', '225.0',
#  '190.0', '170.0', '160.0', '95.00', '97.00', '85.00', '88.00', '46.00',
#  '87.00', '90.00', '113.0', '200.0', '210.0', '193.0',     nan, '100.0',
#  '105.0', '175.0', '153.0', '180.0', '110.0', '72.00', '86.00', '70.00',
#  '76.00', '65.00', '69.00', '60.00', '80.00', '54.00', '208.0', '155.0',
#  '112.0', '92.00', '145.0', '137.0', '158.0', '167.0', '94.00', '107.0',
#  '230.0', '49.00', '75.00', '91.00', '122.0', '67.00', '83.00', '78.00',
#  '52.00', '61.00', '93.00', '148.0', '129.0', '96.00', '71.00', '98.00',
#  '115.0', '53.00', '81.00', '79.00', '120.0', '152.0', '102.0', '108.0',
#  '68.00', '58.00', '149.0', '89.00', '63.00', '48.00', '66.00', '139.0',
#  '103.0', '125.0', '133.0', '138.0', '135.0', '142.0', '77.00', '62.00',
#  '132.0', '84.00', '64.00', '74.00', '116.0', '82.00']
# Length: 94, dtype: str

# %%
df = df.dropna(subset=["horsepower"], axis=0)
df["horsepower"].unique()
# Out:
# <StringArray>
# ['130.0', '165.0', '150.0', '140.0', '198.0', '220.0', '215.0', '225.0',
#  '190.0', '170.0', '160.0', '95.00', '97.00', '85.00', '88.00', '46.00',
#  '87.00', '90.00', '113.0', '200.0', '210.0', '193.0', '100.0', '105.0',
#  '175.0', '153.0', '180.0', '110.0', '72.00', '86.00', '70.00', '76.00',
#  '65.00', '69.00', '60.00', '80.00', '54.00', '208.0', '155.0', '112.0',
#  '92.00', '145.0', '137.0', '158.0', '167.0', '94.00', '107.0', '230.0',
#  '49.00', '75.00', '91.00', '122.0', '67.00', '83.00', '78.00', '52.00',
#  '61.00', '93.00', '148.0', '129.0', '96.00', '71.00', '98.00', '115.0',
#  '53.00', '81.00', '79.00', '120.0', '152.0', '102.0', '108.0', '68.00',
#  '58.00', '149.0', '89.00', '63.00', '48.00', '66.00', '139.0', '103.0',
#  '125.0', '133.0', '138.0', '135.0', '142.0', '77.00', '62.00', '132.0',
#  '84.00', '64.00', '74.00', '116.0', '82.00']
# Length: 93, dtype: str

# %%
df["horsepower"] = df["horsepower"].astype("float")
df["horsepower"].unique()
# Out:
# array([130., 165., 150., 140., 198., 220., 215., 225., 190., 170., 160.,
#         95.,  97.,  85.,  88.,  46.,  87.,  90., 113., 200., 210., 193.,
#        100., 105., 175., 153., 180., 110.,  72.,  86.,  70.,  76.,  65.,
#         69.,  60.,  80.,  54., 208., 155., 112.,  92., 145., 137., 158.,
#        167.,  94., 107., 230.,  49.,  75.,  91., 122.,  67.,  83.,  78.,
#         52.,  61.,  93., 148., 129.,  96.,  71.,  98., 115.,  53.,  81.,
#         79., 120., 152., 102., 108.,  68.,  58., 149.,  89.,  63.,  48.,
#         66., 139., 103., 125., 133., 138., 135., 142.,  77.,  62., 132.,
#         84.,  64.,  74., 116.,  82.])

# %%
df["origin"].unique()
# Out:
# array([1, 3, 2])

# %%
df["origin"] = df["origin"].replace(
    {
        1:"USA",
        2:"EU",
        3:"JAPAN"
     }
)

df["origin"].unique()
# Out:
# array(['USA', 'JAPAN', 'EU'], dtype=object)

# %%
df["origin"].dtype
# Out:
# CategoricalDtype(categories=['EU', 'JAPAN', 'USA'], ordered=False, categories_dtype=str)

# %%
df["origin"] = df["origin"].astype("category")
df['origin']
# Out:
# 0      USA
# 1      USA
# 2      USA
# 3      USA
# 4      USA
#       ...
# 393    USA
# 394     EU
# 395    USA
# 396    USA
# 397    USA
# Name: origin, Length: 392, dtype: category
# Categories (3, str): ['EU', 'JAPAN', 'USA']

# %%
# 범주형 데이터 처리
