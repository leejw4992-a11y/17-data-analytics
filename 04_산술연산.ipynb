# %%
import pandas as pd

# %%
dict_data = {
    "국어" : 100,
    "영어" : 80,
    "수학" : 90
}

student1 = pd.Series(dict_data)
student1
# Out:
# 국어    100
# 영어     80
# 수학     90
# dtype: int64

# %%
percentage = student1 / 200
print(percentage)
print(type(percentage))
# Out:
# 국어    0.50
# 영어    0.40
# 수학    0.45
# dtype: float64
# <class 'pandas.Series'>
