# %% [markdown]
# # 01 제1유형
#
# 기출문제 5회 제1유형 연습입니다.
# 각 문제는 **서로 다른 CSV**를 사용합니다.
#
# **데이터 URL (공통 경로)**
# ```
# https://raw.githubusercontent.com/YoungjinBD/dataset/main/
# ```
#
# > 한글 CSV는 `encoding="cp949"`가 필요할 수 있습니다.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 문제 ① 음식물쓰레기 2L 종량제 봉투 평균 가격
#
# `trash_bag` 데이터는 지역별 종량제 봉투 가격 정보이다.
# 각 용량별 가격 컬럼은 해당 행의 조건을 만족하는 봉투가 존재하면 가격을,
# 존재하지 않으면 0을 값으로 갖는다.
#
# 용도가 **'음식물쓰레기'**이고 사용 대상이 **'가정용'**인 2L 봉투 가격의
# **평균**을 구하시오. (소수점 이하는 **절사**하여 **정수**로 출력)
#
# **데이터**: `trash_bag.csv`
# ```
# https://raw.githubusercontent.com/YoungjinBD/dataset/main/trash_bag.csv
# ```
#
# > 출력: 평균 가격(정수, 절사)

# %%
df1 = pd.read_csv(
    "https://raw.githubusercontent.com/YoungjinBD/dataset/main/trash_bag.csv",
    encoding="cp949",
)
df1.head()

# df1.info()
df1_c = df1[
    (df1["용도"] == "음식물쓰레기") &
    (df1["사용대상"] == "가정용") &
    (df1["2L가격"] > 0 )
]

# df1_c.head()
print(len(df1_c))
print(df1_c["2L가격"].mean())
print(int(df1_c["2L가격"].mean()))


# cond1 = df1["용도"] == "음식물쓰레기"
# cond2 = df1["사용대상"] == "가정용"
# cond = cond1 & cond2
# result_df = df1[cond]

# # int(result_df["2L가격"].mean())

# result_df = result_df[result_df["2L가격"] != 0]
# result_df["가격"].mean()
# Out:
# 52
# 119.32692307692308
# 119

# %% [markdown]
# ## 문제 ② BMI 정상·과체중 인원 수 차이
#
# BMI(Body Mass Index)는 몸무게(kg)를 키(m)의 제곱으로 나누어 계산하며,
# 비만도를 나타내는 지표이다. 아래 기준에 따라 분류한다.
#
# | BMI 범위 | 분류 |
# |---|---|
# | 18.5 미만 | 저체중 |
# | 18.5 이상 ~ 23 미만 | 정상 |
# | 23 이상 ~ 25 미만 | 과체중 |
# | 25 이상 ~ 30 미만 | 경도비만 |
# | 30 이상 | 중등도비만 |
#
# 제공된 BMI 데이터를 기준으로 **정상** 체중 인원과 **과체중** 인원의
# 차이를 정수로 출력하시오.
#
# **데이터**: `BMI.csv`
# ```
# https://raw.githubusercontent.com/YoungjinBD/dataset/main/BMI.csv
# ```
#
# > 출력: (정상 인원 수) − (과체중 인원 수) (정수)

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/YoungjinBD/dataset/main/BMI.csv")
# print(df2.head())

# df2["BMI"] = df2["Weight"] / (df2["Height"] / 100) ** 2
# df2["BMI"]
# df2.head()


# 정상 = (df2["BMI"]>=18.5) & (df2["BMI"]<23).sum()
# # 정상
# 과체중 = (df2["BMI"]>=23) & (df2["BMI"]<25).sum()
# # 과체중

# print(정상,과체중, 정상-과체중)

df2["Height_m"] = df2["Height"]/100
# df2.head()

df2["BMI"] = df2["Weight"] / (df2["Height_m"]) ** 2
df2.head()

normal = (df2["BMI"] >= 18.5) & (df2["BMI"] < 23)
over_w = (df2["BMI"] >= 23) & (df2["BMI"] <25)

len(df2[normal]) - len(df2[over_w])
# Out:
# 28

# %% [markdown]
# ## 문제 ③ 순전입학생 수가 가장 많은 학교
#
# `students` 데이터는 학교별·학년별 **총 전입학생**, **총 전출학생**,
# **전체학생 수** 정보이다.
#
# 순전입학생 수는 다음과 같이 정의한다.
#
# $$\text{순전입학생 수} = \text{총 전입학생} - \text{총 전출학생}$$
#
# **순전입학생 수가 가장 많은 학교**의 **전체학생 수**를 구하시오.
#
# **데이터**: `students.csv`
# ```
# https://raw.githubusercontent.com/YoungjinBD/dataset/main/students.csv
# ```
#
# > 출력: 해당 학교의 전체학생 수

# %%
df3 = pd.read_csv(
    "https://raw.githubusercontent.com/YoungjinBD/dataset/main/students.csv",
    encoding="cp949",
)
df3.head()

df3["순전입학생 수"] = df3["총 전입학생"] - df3["총 전출학생"]
df3.head()
df3.sort_values("순전입학생 수", ascending=False)

grouped = df3.groupby("학교")
grouped.agg("sum").sort_values("순전입학생 수", ascending=False)
# Out:
#     학년  총 전입학생  총 전출학생  전체학생 수  순전입학생 수
# 학교
# A    6      30      12     566       18
# E    6      22       8     603       14
# B    6      22       9     588       13
# G    6      17       7     618       10
# D    6      12       5     548        7
# F    6      17      16     481        1
# H    6      17      18     602       -1
# C    6       5      14     528       -9
